# %% [markdown]
# ### Portfolio assignment 9
# 25 min: Perform a bivariate analysis on the columns with numerical data in the penguins dataset.
# - Use corr() on the DataFrame to calculate all the correlations. Use the code example above to show the correlation table with colors.
# - Look at the corrrelations. Do they match your expectations?
# - Show a scatter plot for
#  - The strongest positive correlation
#  - The strongest negative correlation
#  - The weakest correlation

# %%
import seaborn as sns

# %%
penguins = sns.load_dataset("penguins")

# %%
exampleDataCorrelations = penguins.corr()
exampleDataCorrelations.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# C:\Users\dekei\AppData\Local\Temp\ipykernel_12700\3557949741.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   exampleDataCorrelations.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# <style type="text/css">
# #T_bcb0d_row0_col0, #T_bcb0d_row1_col1, #T_bcb0d_row2_col2, #T_bcb0d_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_bcb0d_row0_col1, #T_bcb0d_row1_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_bcb0d_row0_col2, #T_bcb0d_row2_col0 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_bcb0d_row0_col3, #T_bcb0d_row3_col0 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_bcb0d_row1_col2, #T_bcb0d_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_bcb0d_row1_col3, #T_bcb0d_row3_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_bcb0d_row2_col3, #T_bcb0d_row3_col2 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bcb0d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bcb0d_level0_col0" class="col_heading level0 col0" >bill_length_mm</th>
#       <th id="T_bcb0d_level0_col1" class="col_heading level0 col1" >bill_depth_mm</th>
#       <th id="T_bcb0d_level0_col2" class="col_heading level0 col2" >flipper_length_mm</th>
#       <th id="T_bcb0d_level0_col3" class="col_heading level0 col3" >body_mass_g</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bcb0d_level0_row0" class="row_heading level0 row0" >bill_length_mm</th>
#       <td id="T_bcb0d_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_bcb0d_row0_col1" class="data row0 col1" >-0.24</td>
#       <td id="T_bcb0d_row0_col2" class="data row0 col2" >0.66</td>
#       <td id="T_bcb0d_row0_col3" class="data row0 col3" >0.60</td>
#     </tr>
#     <tr>
#       <th id="T_bcb0d_level0_row1" class="row_heading level0 row1" >bill_depth_mm</th>
#       <td id="T_bcb0d_row1_col0" class="data row1 col0" >-0.24</td>
#       <td id="T_bcb0d_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_bcb0d_row1_col2" class="data row1 col2" >-0.58</td>
#       <td id="T_bcb0d_row1_col3" class="data row1 col3" >-0.47</td>
#     </tr>
#     <tr>
#       <th id="T_bcb0d_level0_row2" class="row_heading level0 row2" >flipper_length_mm</th>
#       <td id="T_bcb0d_row2_col0" class="data row2 col0" >0.66</td>
#       <td id="T_bcb0d_row2_col1" class="data row2 col1" >-0.58</td>
#       <td id="T_bcb0d_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_bcb0d_row2_col3" class="data row2 col3" >0.87</td>
#     </tr>
#     <tr>
#       <th id="T_bcb0d_level0_row3" class="row_heading level0 row3" >body_mass_g</th>
#       <td id="T_bcb0d_row3_col0" class="data row3 col0" >0.60</td>
#       <td id="T_bcb0d_row3_col1" class="data row3 col1" >-0.47</td>
#       <td id="T_bcb0d_row3_col2" class="data row3 col2" >0.87</td>
#       <td id="T_bcb0d_row3_col3" class="data row3 col3" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Strongest positive correlation

# %%
penguins.plot(kind='scatter', x='flipper_length_mm', y='body_mass_g')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
penguins.plot(kind='scatter', x='bill_depth_mm', y='flipper_length_mm')
# Out:
# <AxesSubplot:xlabel='bill_depth_mm', ylabel='flipper_length_mm'>

# %%
penguins.plot(kind='scatter', x='bill_length_mm', y='bill_depth_mm')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='bill_depth_mm'>
